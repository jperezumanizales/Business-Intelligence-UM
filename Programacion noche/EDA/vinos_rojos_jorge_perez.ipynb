# %%
import pandas as pd
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
import seaborn as sns
import numpy as np  
import seaborn as sns  
import matplotlib.pyplot as plt  
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler 
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import scipy.stats as st
from termcolor import colored
import pandas as pd

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/file/d/1pPiFkbg0rypEsIkAaSoMafJ9GLyQBV73/view?usp=sharing'
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('winequality-red.csv') 
df = pd.read_csv('winequality-red.csv', sep=';')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# El conjunto de datos no tiene valores nulos, El conjunto de datos tiene 1599 filas y 12 columnas.

# %%
df.describe().T.style.background_gradient(cmap = "magma")
# Out:
# <style type="text/css">
# #T_6fb0a_row0_col0, #T_6fb0a_row1_col0, #T_6fb0a_row1_col7, #T_6fb0a_row2_col0, #T_6fb0a_row2_col3, #T_6fb0a_row2_col4, #T_6fb0a_row2_col7, #T_6fb0a_row3_col0, #T_6fb0a_row4_col0, #T_6fb0a_row4_col1, #T_6fb0a_row4_col2, #T_6fb0a_row4_col3, #T_6fb0a_row4_col4, #T_6fb0a_row4_col5, #T_6fb0a_row4_col6, #T_6fb0a_row4_col7, #T_6fb0a_row5_col0, #T_6fb0a_row6_col0, #T_6fb0a_row7_col0, #T_6fb0a_row7_col2, #T_6fb0a_row7_col7, #T_6fb0a_row8_col0, #T_6fb0a_row9_col0, #T_6fb0a_row10_col0, #T_6fb0a_row11_col0 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_6fb0a_row0_col1, #T_6fb0a_row10_col6 {
#   background-color: #311165;
#   color: #f1f1f1;
# }
# #T_6fb0a_row0_col2, #T_6fb0a_row0_col7, #T_6fb0a_row3_col1, #T_6fb0a_row3_col7, #T_6fb0a_row8_col6 {
#   background-color: #07061c;
#   color: #f1f1f1;
# }
# #T_6fb0a_row0_col3 {
#   background-color: #ca3e72;
#   color: #f1f1f1;
# }
# #T_6fb0a_row0_col4 {
#   background-color: #6d1d81;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# en esta grafica podemos decir que al cuando mayor es es la calidad del alcohol, mayor seria la calidad del vino y los vinos que tienen una calidad mayor a 6.5 se consideran buenos

# %%
sns.barplot(df['quality'], df['alcohol'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# la mayoria de vinos tiene 9 y 10 grados de alcohol

# %%
df.plot.scatter(y="chlorides",x="alcohol")
